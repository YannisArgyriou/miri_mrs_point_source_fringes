# %% [markdown]
# # Show fringe correction improvement on crowded field

# %% [markdown]
# ### Define path to data and set flags

# %% [markdown]
# ### <font color='green'> --Modify following path to the folder where the miri_mrs_point_source_fringes folder resides </font>

# %%
user_dir = '/Users/ioannisa/Desktop/python/miri_mrs_point_source_fringes/'

# %% [markdown]
# ### <font color='green'> --Choose if you wish to save plots (default is True) </font>

# %%
save_plots = True

# %% [markdown]
# ### <font color='red'> --Do NOT change following paths </font>

# %%
datapath   = user_dir+'data/'
figurepath = user_dir+'figures/'
outputpath = user_dir+'output_files/'

# %%
import itertools
import numpy as np
from astropy.io import fits
from scipy.ndimage import gaussian_filter
from matplotlib import pyplot as plt
from matplotlib.lines import Line2D

import sys
sys.path.append(user_dir)
from core.funcs import detpixel_trace,detpixel_trace_compactsource,detpixel_isolambda

# %%
# %matplotlib notebook

# %% [markdown]
# ### Preamble

# %% [markdown]
# ### --MRS auxilliary data

# %%
band = '1A'

# %% [markdown]
# ### --Load data

# %%
sci_img        = fits.open(datapath+'CV2_P0.fits')[1].data
fringe_flat    = np.load(datapath+'fringe_flat.npy')
spectral_response = np.load(datapath+'spectral_response.npy')

# %% [markdown]
# ### --Apply spectral response correction

# %%
sci_img /= spectral_response

# %% [markdown]
# ### --Load point source fringe flat from notebook 4

# %%
ps_fringe_flat = np.load(outputpath+'ps_fringe_flat.npy')

# %% [markdown]
# ### Simulate crowded field
# * Omit signals below 0.8mJy/pix (noise dominated)

# %%
crowded_field_img  = sci_img + 2*np.roll(sci_img,2,axis=1)

fig, (axs0, axs1) = plt.subplots(1, 2, figsize=(12, 6), gridspec_kw={'wspace':0,'width_ratios': [1, 3]})
axs0.plot(sci_img[512,22:36],np.arange(22,36),alpha=0.4,label='Point source 1')
axs0.plot((2*np.roll(sci_img,2,axis=1))[512,22:36],np.arange(22,36),alpha=0.4,label='Point source 2')
axs0.plot(crowded_field_img[512,22:36],np.arange(22,36),label='Point source 1+2' )
axs0.hlines(np.arange(24,33),0,60,alpha=0.2)
axs0.set_xlim(0,60)
axs0.set_ylim(23,33.2)
axs0.set_xlabel('Signal [mJy/pix]')
axs0.set_ylabel('Detector column')
axs0.legend(loc='upper left',framealpha=1)
axs0.invert_xaxis()
for col in range(24,33):
    sel = (crowded_field_img[:,col]>0.8) & ~((np.arange(1024)>647) & (np.arange(1024)<653))
    residuals_fringe_flat    = 2*(((crowded_field_img/fringe_flat)[:,col][sel]/gaussian_filter((crowded_field_img/fringe_flat)[:,col][sel],5))-1)
    residuals_ps_fringe_flat = 2*((((sci_img/ps_fringe_flat) + 2*np.roll(sci_img/ps_fringe_flat,2,axis=1))[:,col][sel]/gaussian_filter(((sci_img/ps_fringe_flat) + 2*np.roll(sci_img/ps_fringe_flat,2,axis=1))[:,col][sel],5))-1)
    axs1.plot(np.arange(1024)[sel],col+residuals_fringe_flat,'k')
    axs1.plot(np.arange(1024)[sel],col+residuals_ps_fringe_flat,'r')
    axs1.text(430, col+0.4, r'1$\sigma$ = {}%   vs'.format(round(100*np.std(residuals_fringe_flat)/2.,1)),color='k')
    axs1.text(580, col+0.4, r'{}%'.format(round(100*np.std(residuals_ps_fringe_flat)/2.,1)),color='r')
axs1.hlines(np.arange(24,33),-5,1024,alpha=0.2)
legend_elements = [Line2D([0],[0],color='k',label='fringe_flat'),
                   Line2D([0],[0],color='r',label='ps_fringe_flat')]
axs1.legend(loc='upper left',handles=legend_elements,framealpha=1)
axs1.set_xlim(0,1024)
axs1.set_ylim(23,33.2)
axs1.set_yticks([])
axs1.set_xlabel('Detector row')
fig.tight_layout()
if save_plots:
    plt.savefig(figurepath+'crowded_field_residuals.pdf',dpi=2540)
# Out:
# <img src="data:image/png;base64,..." width="1200">
# /Users/ioannisa/Applications/anaconda3/envs/miricle.devel/lib/python3.6/site-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in greater
#   from ipykernel import kernelapp as app
